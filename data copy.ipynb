# %% [markdown]
# ### Monitoring of the water extent of Lake Neusiedl and the Lacken:
#
# #### Data Preparation

# %% [markdown]
# #### Libraries

# %%
import os
import glob
from osgeo import gdal
import pprint
import numpy as np
import matplotlib.pyplot as plt
from yeoda.datacube import DataCubeReader, DataCubeWriter
from geopathfinder.naming_conventions.yeoda_naming import YeodaFilename
import pandas as pd
import time
import rasterio
import glob
from rasterio.plot import show
import rasterio
import numpy as np
from rasterio.merge import merge
from rasterio.plot import show
from osgeo import gdal
from data_func import merge_files_and_split, ImageDataset, make_list, visualize_augmentations
import warnings
import numpy as np
import glob
from six.moves import xrange
import scipy.ndimage as ndi
import os
from albumentations.pytorch import ToTensorV2
import tensorflow as tf
import torch
from torch.utils.data import TensorDataset, DataLoader, Dataset
import cv2
import shutil
import albumentations as A
import sys
from PIL import Image, ImageOps, ImageFile
import copy

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# pip install scipy
seed = 42


def set_seed(seed):
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)


set_seed(seed)

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# del sys.modules['data_func']

# %% [markdown]
# #### Reading Data

# %%
tile_1 = r"./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E053N015T1"
tile_1 = glob.glob(os.path.join(tile_1, "*"))

# %%
tile_2 = r"./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E052N015T1"
tile_2 = glob.glob(os.path.join(tile_2, "*"))

# %%
mask1 = r"./e11739391/reference/EQUI7_EU010M/E052N015T1"
mask1 = glob.glob(os.path.join(mask1, "*"))

mask2 = r"./e11739391/reference/EQUI7_EU010M/E053N015T1"
mask2 = glob.glob(os.path.join(mask2, "*"))

# %%
dimensions = ["time", "tile_name", "var_name", "sensor_field", "data_version"]
tile1_reader = DataCubeReader.from_filepaths(tile_1, fn_class=YeodaFilename, dimensions=dimensions,
                                             stack_dimension="time", tile_dimension="tile_name")
tile1_reader.file_register.head(5)
# Out:
#                                             filepath sensor_field  \
# 0  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E053N...    S1AIWGRDH
# 1  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E053N...    S1AIWGRDH
# 2  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E053N...    S1AIWGRDH
# 3  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E053N...    S1AIWGRDH
# 4  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E053N...    S1AIWGRDH
#
#   data_version   tile_name var_name                time
# 0      V1M0R01  E053N015T1    GMR40 2022-09-22 16:42:50
# 1      V1M0R01  E053N015T1    GMR40 2022-01-17 05:02:29
# 2      V1M0R01  E053N015T1    GMR40 2022-06-10 05:02:33
# 3      V1M0R01  E053N015T1    GMR40 2022-04-11 05:02:29
# 4      V1M0R01  E053N015T1    GMR40 2022-12-07 05:02:12

# %%
tile2_reader = DataCubeReader.from_filepaths(tile_2, fn_class=YeodaFilename, dimensions=dimensions,
                                             stack_dimension="time", tile_dimension="tile_name")
tile2_reader.file_register.head(5)
# Out:
#                                             filepath sensor_field  \
# 0  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E052N...    S1AIWGRDH
# 1  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E052N...    S1AIWGRDH
# 2  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E052N...    S1AIWGRDH
# 3  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E052N...    S1AIWGRDH
# 4  ./e11739391/Sentinel-1_CSAR/EQUI7_EU010M/E052N...    S1AIWGRDH
#
#   data_version   tile_name var_name                time
# 0      V1M0R01  E052N015T1    GMR40 2022-06-10 05:02:08
# 1      V1M0R01  E052N015T1    GMR40 2022-12-07 05:02:37
# 2      V1M0R01  E052N015T1    GMR40 2022-10-20 05:02:13
# 3      V1M0R01  E052N015T1    GMR40 2022-02-10 05:02:04
# 4      V1M0R01  E052N015T1    GMR40 2022-03-06 05:02:03

# %%
tile1_reader.file_register.sort_values(by='time')['time'].unique()
# Out:
# <DatetimeArray>
# ['2022-01-17 05:02:04', '2022-01-17 05:02:29', '2022-02-10 05:02:04',
#  '2022-02-10 05:02:29', '2022-03-06 05:02:03', '2022-03-06 05:02:28',
#  '2022-04-11 05:02:04', '2022-04-11 05:02:29', '2022-05-17 05:02:05',
#  '2022-05-17 05:02:30', '2022-06-10 05:02:08', '2022-06-10 05:02:33',
#  '2022-07-24 16:42:48', '2022-07-24 16:43:13', '2022-08-05 16:42:49',
#  '2022-08-05 16:43:14', '2022-09-22 16:42:50', '2022-09-22 16:43:15',
#  '2022-10-20 05:02:13', '2022-10-20 05:02:38', '2022-11-01 05:02:13',
#  '2022-11-01 05:02:38', '2022-12-07 05:02:12', '2022-12-07 05:02:37']
# Length: 24, dtype: datetime64[ns]

# %%
mask1_reader = DataCubeReader.from_filepaths(mask1, fn_class=YeodaFilename, dimensions=dimensions,
                                             stack_dimension="time", tile_dimension="tile_name")
mask2_reader = DataCubeReader.from_filepaths(mask2, fn_class=YeodaFilename, dimensions=dimensions,
                                             stack_dimension="time", tile_dimension="tile_name")

# %%
mask2_reader.file_register.head(5)
# Out:
#                                             filepath sensor_field  \
# 0  ./e11739391/reference/EQUI7_EU010M/E053N015T1/...         None
# 1  ./e11739391/reference/EQUI7_EU010M/E053N015T1/...         None
# 2  ./e11739391/reference/EQUI7_EU010M/E053N015T1/...         None
# 3  ./e11739391/reference/EQUI7_EU010M/E053N015T1/...         None
# 4  ./e11739391/reference/EQUI7_EU010M/E053N015T1/...         None
#
#   data_version   tile_name var_name       time
# 0         None  E053N015T1     MASK 2022-08-05
# 1         None  E053N015T1     MASK 2022-01-17
# 2         None  E053N015T1     MASK 2022-04-11
# 3         None  E053N015T1     MASK 2022-09-22
# 4         None  E053N015T1     MASK 2022-07-24

# %%
mask1_reader.file_register.head(5)
# Out:
#                                             filepath sensor_field  \
# 0  ./e11739391/reference/EQUI7_EU010M/E052N015T1/...         None
# 1  ./e11739391/reference/EQUI7_EU010M/E052N015T1/...         None
# 2  ./e11739391/reference/EQUI7_EU010M/E052N015T1/...         None
# 3  ./e11739391/reference/EQUI7_EU010M/E052N015T1/...         None
# 4  ./e11739391/reference/EQUI7_EU010M/E052N015T1/...         None
#
#   data_version   tile_name var_name       time
# 0         None  E052N015T1     MASK 2022-05-17
# 1         None  E052N015T1     MASK 2022-01-17
# 2         None  E052N015T1     MASK 2022-10-20
# 3         None  E052N015T1     MASK 2022-12-07
# 4         None  E052N015T1     MASK 2022-05-17

# %% [markdown]
# #### Merging files

# %%
df_concat = pd.concat([tile1_reader.file_register, tile2_reader.file_register], axis=0)

# %%
df_concat.head(5)

# %%
merge_files_and_split(df_concat, 'VV')

# %%
merge_files_and_split(df_concat, 'VH')

# %%
df_concat_mask = pd.concat([mask1_reader.file_register, mask2_reader.file_register], axis=0)

# %%
merge_files_and_split(df_concat_mask, notmask=False)

# %%
test_mask = "./train_mask/VV_mask_2022-02-10_merged.tiff"
test_img = "./train/VH_2022-02-10_merged.tiff"

# %%
import cv2
from PIL import Image
Image.MAX_IMAGE_PIXELS = 300000000  # Set a custom limit, e.g., 300 million pixels

# %%
x = rasterio.open(test_img)
image_data = x.read(1)
plt.imshow(image_data)
plt.title("Merged image")
# Out:
# Text(0.5, 1.0, 'Merged image')

# %%
x = rasterio.open(test_mask)
image_data = x.read(1)
plt.imshow(image_data)
plt.title("Merged image")
plt.figsize = (4, 6)

# %%
# Image.MAX_IMAGE_PIXELS = None
# ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
train = "./train/*.tiff"
mask_train = "./train_mask/*.tiff"
test = "./test/*.tiff"
mask_test = "./test_mask/*.tiff"
val = "./val/*.tiff"
mask_val = "./val_mask/*.tiff"

# %%
make_list(train, mask_train, 'train')
make_list(test, mask_test, 'test')
make_list(val, mask_val, 'val')

# %%
np.array(pil_image.convert("RGB"))
